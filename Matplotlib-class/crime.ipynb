# %%
# %matplotlib notebook
import pandas as pd
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from random import random

from scipy.stats import sem

# %%
crime_data=pd.read_csv("crime_data.csv")
crime_data.head()
# Out:
#      year   population  violent crime  violent crime rate  \
# 0  1994.0  260327021.0      1857670.0               713.6
# 1  1995.0  262803276.0      1798792.0               684.5
# 2  1996.0  265228572.0      1688540.0               636.6
# 3  1997.0  267783607.0      1636096.0               611.0
# 4  1998.0  270248003.0      1533887.0               567.6
#
#    murder and non-negligent manslaughter  \
# 0                                23326.0
# 1                                21606.0
# 2                                19645.0
# 3                                18208.0
# 4                                16974.0
#
#     murder and non-negligent manslaughter rate      rape  rape rate   robbery  \
# 0                                          9.0  102216.0       39.3  618949.0
# 1                                          8.2   97470.0       37.1  580509.0
# 2                                          7.4   96252.0       36.3  535594.0
# ...

# %%
year=crime_data.iloc[:,0]
violent_crime_rate=crime_data.iloc[:,3]
murder_rate=crime_data.iloc[:,5]
aggravated_assault_rate=crime_data.iloc[:,11]
avg_violment_crime_rate=violent_crime_rate.mean()
avg_murder_rate=murder_rate.mean()
avg_aggravated_assault_rate=aggravated_assault_rate.mean()

# %%
avg_aggravated_assault_rate=aggravated_assault_rate.mean()
avg_aggravated_assault_rate
# Out:
# 311.46000000000004

# %%
(slope, intercept, _, _, _) = linregress(year, violent_crime_rate)
fit = slope * year + intercept
fig, ax = plt.subplots()
fig.suptitle("Violent Crime Rate", fontsize=16, fontweight="bold")
ax.set_xlim(1990, 1000)
ax.set_ylim(100000, 100000000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.6296748146958">
