# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 640

# %%
#Perform a weather check on each city using a series of successive API calls.
#Include a print log of each city as it'sbeing processed (with the city number and city name).

url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=mataura
# Processing Record 2 | Khandagayty
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=khandagayty
# Processing Record 3 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=pevek
# Processing Record 4 | Boulder City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=boulder city
# City not found. Skipping...
# Processing Record 5 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=cape town
# Processing Record 6 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=provideniya
# Processing Record 7 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=hobart
# Processing Record 8 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=jamestown
# Processing Record 9 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=rikitea
# Processing Record 10 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=tiksi
# Processing Record 11 | Roald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=roald
# Processing Record 12 | Monastyrshchina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=monastyrshchina
# Processing Record 13 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=punta arenas
# Processing Record 14 | Saint-Augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=saint-augustin
# Processing Record 15 | Maumere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=maumere
# Processing Record 16 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=luderitz
# City not found. Skipping...
# Processing Record 17 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=bredasdorp
# Processing Record 18 | Saint Anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=saint anthony
# Processing Record 19 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=lompoc
# Processing Record 20 | Savannah Bight
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=savannah bight
# Processing Record 21 | Manjacaze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=manjacaze
# Processing Record 22 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=castro
# Processing Record 23 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=sao filipe
# Processing Record 24 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=busselton
# Processing Record 25 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=bluff
# Processing Record 26 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=atuona
# Processing Record 27 | Ojinaga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=ojinaga
# Processing Record 28 | Souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=souillac
# Processing Record 29 | Porbandar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=porbandar
# Processing Record 30 | Itacare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=itacare
# City not found. Skipping...
# Processing Record 31 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=hambantota
# Processing Record 32 | Mackay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=mackay
# Processing Record 33 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=saskylakh
# Processing Record 34 | Eureka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=eureka
# Processing Record 35 | Kampot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=kampot
# Processing Record 36 | Turkan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=turkan
# Processing Record 37 | Mainburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=mainburg
# Processing Record 38 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=torbay
# Processing Record 39 | Choix
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=choix
# Processing Record 40 | Pangkalanbuun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=pangkalanbuun
# Processing Record 41 | Byron Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=byron bay
# Processing Record 42 | Mbala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=mbala
# Processing Record 43 | Minab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=minab
# Processing Record 44 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=avarua
# Processing Record 45 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=tuktoyaktuk
# Processing Record 46 | Chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=chapais
# Processing Record 47 | Lufilufi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=lufilufi
# City not found. Skipping...
# Processing Record 48 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=chokurdakh
# Processing Record 49 | Athabasca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=athabasca
# Processing Record 50 | Twin Falls
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=twin falls
# Processing Record 51 | Maihar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=maihar
# Processing Record 52 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=new norfolk
# Processing Record 53 | Durango
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=durango
# Processing Record 54 | Itaituba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=itaituba
# Processing Record 55 | Tual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=tual
# Processing Record 56 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=albany
# Processing Record 57 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=upernavik
# City not found. Skipping...
# Processing Record 58 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=vaini
# Processing Record 59 | Kotelnikovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=kotelnikovo
# Processing Record 60 | San Andres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=san andres
# Processing Record 61 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=east london
# Processing Record 62 | Victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=victoria
# Processing Record 63 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=tasiilaq
# Processing Record 64 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=hilo
# City not found. Skipping...
# Processing Record 65 | Waipawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=waipawa
# Processing Record 66 | Shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=shimoda
# Processing Record 67 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=kapaa
# Processing Record 68 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=fortuna
# Processing Record 69 | Porto Velho
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=porto velho
# Processing Record 70 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=thompson
# Processing Record 71 | Grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=grindavik
# Processing Record 72 | Dicabisagan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=dicabisagan
# City not found. Skipping...
# Processing Record 73 | Ippy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=ippy
# Processing Record 74 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=ushuaia
# Processing Record 75 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=bathsheba
# Processing Record 76 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=faanui
# Processing Record 77 | Kitimat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=kitimat
# Processing Record 78 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=kodiak
# Processing Record 79 | Arequipa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=arequipa
# Processing Record 80 | Kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=kloulklubed
# Processing Record 81 | Klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=klaksvik
# Processing Record 82 | Handia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=handia
# Processing Record 83 | Cabral
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=cabral
# Processing Record 84 | Sarakhs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=sarakhs
# Processing Record 85 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=constitucion
# Processing Record 86 | Veraval
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=veraval
# City not found. Skipping...
# Processing Record 87 | Troitsko-Pechorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=troitsko-pechorsk
# Processing Record 88 | Waitara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=waitara
# Processing Record 89 | Sharan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=sharan
# Processing Record 90 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=bambous virieux
# Processing Record 91 | Verkhnevilyuysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=verkhnevilyuysk
# Processing Record 92 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=bethel
# Processing Record 93 | Chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=chuy
# Processing Record 94 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=kahului
# Processing Record 95 | Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=saint-pierre
# Processing Record 96 | Mbandaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=mbandaka
# Processing Record 97 | Yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=yulara
# City not found. Skipping...
# Processing Record 98 | Tyrma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=tyrma
# Processing Record 99 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=qaanaaq
# Processing Record 100 | Roebourne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=roebourne
# Processing Record 101 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=butaritari
# Processing Record 102 | Boa Vista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=boa vista
# Processing Record 103 | Hirara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=hirara
# Processing Record 104 | Tipuani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=tipuani
# Processing Record 105 | Mogwase
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=mogwase
# Processing Record 106 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=esperance
# City not found. Skipping...
# Processing Record 107 | Sakaiminato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=sakaiminato
# City not found. Skipping...
# Processing Record 108 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=khatanga
# Processing Record 109 | Rantauprapat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=rantauprapat
# Processing Record 110 | Rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=rawson
# Processing Record 111 | Kirakira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=kirakira
# Processing Record 112 | Lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=lasa
# Processing Record 113 | Mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=mayo
# Processing Record 114 | College
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=college
# Processing Record 115 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=cherskiy
# Processing Record 116 | Baft
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=baft
# Processing Record 117 | Mirebalais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=mirebalais
# Processing Record 118 | Kabalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=kabalo
# City not found. Skipping...
# Processing Record 119 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=clyde river
# Processing Record 120 | Tigil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=tigil
# Processing Record 121 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=barrow
# Processing Record 122 | Kontagora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=kontagora
# City not found. Skipping...
# Processing Record 123 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=ilulissat
# City not found. Skipping...
# Processing Record 124 | Wattegama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=wattegama
# Processing Record 125 | Port-Gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=port-gentil
# Processing Record 126 | Riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=riyadh
# Processing Record 127 | Methoni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=methoni
# Processing Record 128 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=hithadhoo
# Processing Record 129 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=cidreira
# Processing Record 130 | Ust-Omchug
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=ust-omchug
# Processing Record 131 | Brigantine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=brigantine
# Processing Record 132 | Mayumba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=mayumba
# Processing Record 133 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=hermanus
# Processing Record 134 | Mangai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=mangai
# Processing Record 135 | Verkhoyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=verkhoyansk
# Processing Record 136 | Ishigaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=ishigaki
# City not found. Skipping...
# Processing Record 137 | Minuri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=minuri
# Processing Record 138 | Gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=gizo
# Processing Record 139 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=ribeira grande
# Processing Record 140 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=puerto ayora
# Processing Record 141 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=port alfred
# Processing Record 142 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=saint george
# Processing Record 143 | Broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=broome
# Processing Record 144 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=geraldton
# Processing Record 145 | Gardez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=gardez
# Processing Record 146 | Margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=margate
# Processing Record 147 | Baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=baykit
# Processing Record 148 | Tungor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=tungor
# Processing Record 149 | Storforshei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=storforshei
# Processing Record 150 | Miquelon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=miquelon
# Processing Record 151 | Abbeville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=abbeville
# Processing Record 152 | Luwuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=luwuk
# Processing Record 153 | San Nicolas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=san nicolas
# Processing Record 154 | Oistins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=oistins
# Processing Record 155 | Pitimbu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=pitimbu
# Processing Record 156 | Hlukhiv
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=hlukhiv
# Processing Record 157 | Sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=sola
# Processing Record 158 | Batagay-Alyta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=batagay-alyta
# Processing Record 159 | Vilhena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=vilhena
# Processing Record 160 | Ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=ancud
# Processing Record 161 | Lahaina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=lahaina
# Processing Record 162 | Lashio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=lashio
# City not found. Skipping...
# Processing Record 163 | Sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=sitka
# Processing Record 164 | Ballina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=ballina
# Processing Record 165 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=airai
# Processing Record 166 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=lebu
# Processing Record 167 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=arraial do cabo
# City not found. Skipping...
# Processing Record 168 | Fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=fairbanks
# Processing Record 169 | Hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=hualmay
# Processing Record 170 | Kupang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=kupang
# Processing Record 171 | Chimbote
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=chimbote
# Processing Record 172 | Muzhi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=muzhi
# Processing Record 173 | Broken Hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=broken hill
# Processing Record 174 | Rio Gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=rio gallegos
# Processing Record 175 | Kathmandu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=kathmandu
# Processing Record 176 | Ust-Uda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=ust-uda
# Processing Record 177 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=dikson
# Processing Record 178 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=norman wells
# Processing Record 179 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=saint-philippe
# Processing Record 180 | Evensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=evensk
# Processing Record 181 | Ostersund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=ostersund
# City not found. Skipping...
# Processing Record 182 | Davila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=davila
# Processing Record 183 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=kaitangata
# Processing Record 184 | Toamasina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=toamasina
# Processing Record 185 | Axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=axim
# Processing Record 186 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=ponta do sol
# Processing Record 187 | Mglin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=mglin
# Processing Record 188 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=carnarvon
# Processing Record 189 | Churapcha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=churapcha
# Processing Record 190 | Xianshuigu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=xianshuigu
# Processing Record 191 | Cap-aux-Meules
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=cap-aux-meules
# City not found. Skipping...
# Processing Record 192 | Paita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=paita
# Processing Record 193 | Launceston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=launceston
# Processing Record 194 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=mount gambier
# Processing Record 195 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=te anau
# Processing Record 196 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=nikolskoye
# Processing Record 197 | Bowmore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=bowmore
# Processing Record 198 | Dutse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=dutse
# Processing Record 199 | Pandan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=pandan
# Processing Record 200 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=mar del plata
# Processing Record 201 | Kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=kalmunai
# Processing Record 202 | Tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=tilichiki
# Processing Record 203 | Mosina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=mosina
# Processing Record 204 | Isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=isangel
# Processing Record 205 | Vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=vardo
# Processing Record 206 | Christchurch
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=christchurch
# Processing Record 207 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=lorengau
# City not found. Skipping...
# Processing Record 208 | Cherdyn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=cherdyn
# Processing Record 209 | Sorong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=sorong
# Processing Record 210 | Bowen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=bowen
# Processing Record 211 | Dannenberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=dannenberg
# City not found. Skipping...
# Processing Record 212 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=port elizabeth
# Processing Record 213 | Taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=taoudenni
# Processing Record 214 | Touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=touros
# Processing Record 215 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=katsuura
# Processing Record 216 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=mahebourg
# Processing Record 217 | Nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=nouadhibou
# Processing Record 218 | Kilindoni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=kilindoni
# Processing Record 219 | Pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=pisco
# Processing Record 220 | Bonavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=bonavista
# Processing Record 221 | Havelock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=havelock
# Processing Record 222 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=yellowknife
# Processing Record 223 | Mangrol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=mangrol
# Processing Record 224 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=cabo san lucas
# Processing Record 225 | Manyana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=manyana
# Processing Record 226 | Abu Dhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=abu dhabi
# Processing Record 227 | Talcahuano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=talcahuano
# Processing Record 228 | Komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=komsomolskiy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 229 | Soni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=soni
# Processing Record 230 | Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=ostrovnoy
# Processing Record 231 | Chapada dos Guimaraes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=chapada dos guimaraes
# Processing Record 232 | Lazaro Cardenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=lazaro cardenas
# Processing Record 233 | Tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=tessalit
# Processing Record 234 | Vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=vostok
# Processing Record 235 | Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=severo-kurilsk
# Processing Record 236 | Houlton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=houlton
# Processing Record 237 | Brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=brae
# Processing Record 238 | Mugur-Aksy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=mugur-aksy
# Processing Record 239 | Banhigan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=banhigan
# Processing Record 240 | Rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=rocha
# Processing Record 241 | Mount Isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=mount isa
# Processing Record 242 | Guanica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=guanica
# Processing Record 243 | Gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=gamba
# Processing Record 244 | Elat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=elat
# Processing Record 245 | Auki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=auki
# City not found. Skipping...
# Processing Record 246 | Saint-Leu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=saint-leu
# Processing Record 247 | Husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=husavik
# Processing Record 248 | Zalantun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=zalantun
# City not found. Skipping...
# Processing Record 249 | Rorvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=rorvik
# Processing Record 250 | Hervey Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=hervey bay
# Processing Record 251 | Dombarovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=dombarovskiy
# Processing Record 252 | Coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=coahuayana
# Processing Record 253 | Huanren
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=huanren
# Processing Record 254 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=los llanos de aridane
# Processing Record 255 | Salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=salalah
# Processing Record 256 | Boueni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=boueni
# Processing Record 257 | Cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=cayenne
# Processing Record 258 | Dandong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=dandong
# Processing Record 259 | Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=lavrentiya
# Processing Record 260 | Ponta Delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=ponta delgada
# City not found. Skipping...
# Processing Record 261 | Manokwari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=manokwari
# Processing Record 262 | Madang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=madang
# Processing Record 263 | Aldama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=aldama
# Processing Record 264 | Ibia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=ibia
# Processing Record 265 | Port Hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=port hedland
# Processing Record 266 | Kodinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=kodinsk
# Processing Record 267 | Hokitika
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=hokitika
# Processing Record 268 | Harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=harper
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 269 | Talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=talnakh
# Processing Record 270 | Port Hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=port hardy
# Processing Record 271 | Paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=paamiut
# Processing Record 272 | Saquena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=saquena
# Processing Record 273 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=nanortalik
# Processing Record 274 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=georgetown
# Processing Record 275 | Sambava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=sambava
# Processing Record 276 | Mudkhed
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=mudkhed
# Processing Record 277 | Goma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=goma
# Processing Record 278 | Muskegon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=muskegon
# Processing Record 279 | Hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=hamilton
# Processing Record 280 | Tabou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=tabou
# Processing Record 281 | Mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=mehamn
# Processing Record 282 | Berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=berlevag
# Processing Record 283 | The Valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=the valley
# Processing Record 284 | Rabo de Peixe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=rabo de peixe
# Processing Record 285 | Makakilo City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=makakilo city
# Processing Record 286 | Yekaterinovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=yekaterinovka
# Processing Record 287 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=coquimbo
# Processing Record 288 | Sioux Lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=sioux lookout
# Processing Record 289 | Zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=zhigansk
# Processing Record 290 | Hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=hami
# City not found. Skipping...
# Processing Record 291 | Dobryanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=dobryanka
# Processing Record 292 | Blanquefort
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=blanquefort
# Processing Record 293 | Magistralnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=magistralnyy
# Processing Record 294 | Bagan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=bagan
# Processing Record 295 | Codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=codrington
# Processing Record 296 | Linjiang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=linjiang
# Processing Record 297 | Sao Joao da Barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=sao joao da barra
# Processing Record 298 | Naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=naze
# Processing Record 299 | Ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=ketchikan
# Processing Record 300 | Xining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=xining
# City not found. Skipping...
# Processing Record 301 | Umm Lajj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=umm lajj
# Processing Record 302 | Maun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=maun
# City not found. Skipping...
# Processing Record 303 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=narsaq
# Processing Record 304 | Itamarandiba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=itamarandiba
# Processing Record 305 | Chipiona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=chipiona
# Processing Record 306 | Honningsvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=honningsvag
# Processing Record 307 | Aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=aykhal
# City not found. Skipping...
# Processing Record 308 | Zyryanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=zyryanka
# Processing Record 309 | Kathu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=kathu
# Processing Record 310 | Itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=itarema
# Processing Record 311 | Haifa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=haifa
# City not found. Skipping...
# Processing Record 312 | Qom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=qom
# Processing Record 313 | La Cruz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=la cruz
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 314 | Berezovyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=berezovyy
# Processing Record 315 | Tongchuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=tongchuan
# Processing Record 316 | Dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=dingle
# Processing Record 317 | Lappeenranta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=lappeenranta
# Processing Record 318 | Mae Ramat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=mae ramat
# Processing Record 319 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=aklavik
# Processing Record 320 | Guzelyurt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=guzelyurt
# Processing Record 321 | North Las Vegas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=north las vegas
# Processing Record 322 | Machiques
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=machiques
# Processing Record 323 | Razdolinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=razdolinsk
# Processing Record 324 | Gijon
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=samfya
# City not found. Skipping...
# Processing Record 473 | Cururupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=cururupu
# Processing Record 474 | Mari-Turek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=mari-turek
# Processing Record 475 | Wewak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=wewak
# Processing Record 476 | Nizwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=nizwa
# Processing Record 477 | Khasan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=khasan
# Processing Record 478 | Aksu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=aksu
# Processing Record 479 | Kotagiri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=kotagiri
# Processing Record 480 | Caraquet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=caraquet
# Processing Record 481 | Flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=flinders
# City not found. Skipping...
# Processing Record 482 | Jalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=jalu
# Processing Record 483 | Guane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=guane
# Processing Record 484 | Miraflores
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=miraflores
# Processing Record 485 | Norcasia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=norcasia
# Processing Record 486 | Bako
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=bako
# Processing Record 487 | Burnie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=burnie
# Processing Record 488 | Chateau-Gontier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=chateau-gontier
# Processing Record 489 | Aberystwyth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=aberystwyth
# Processing Record 490 | Iralaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=iralaya
# Processing Record 491 | Vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=vanimo
# Processing Record 492 | Eyemouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=eyemouth
# Processing Record 493 | Meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=meulaboh
# Processing Record 494 | Loa Janan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=loa janan
# Processing Record 495 | Santa Rosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=santa rosa
# Processing Record 496 | Posse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=posse
# City not found. Skipping...
# Processing Record 497 | Arshan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=arshan
# Processing Record 498 | Pouembout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=pouembout
# Processing Record 499 | Dubbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=dubbo
# Processing Record 500 | Petrivka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=petrivka
# Processing Record 501 | Pacific Grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=pacific grove
# Processing Record 502 | Khandela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=khandela
# Processing Record 503 | Half Moon Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=half moon bay
# Processing Record 504 | Beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=beringovskiy
# Processing Record 505 | Arman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=arman
# Processing Record 506 | Kerema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=kerema
# Processing Record 507 | Nikel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=nikel
# Processing Record 508 | Qandala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=qandala
# Processing Record 509 | Saint-Felix-de-Valois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=saint-felix-de-valois
# Processing Record 510 | Hadejia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=hadejia
# City not found. Skipping...
# Processing Record 511 | Malpe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=malpe
# Processing Record 512 | Sebring
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=sebring
# Processing Record 513 | Karpathos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=karpathos
# Processing Record 514 | Vega de Alatorre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=vega de alatorre
# Processing Record 515 | Otofuke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=otofuke
# Processing Record 516 | Benguela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=benguela
# Processing Record 517 | Morehead
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=morehead
# Processing Record 518 | General Bravo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=general bravo
# Processing Record 519 | Mandalgovi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=mandalgovi
# Processing Record 520 | Chingirlau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=chingirlau
# Processing Record 521 | Trinidad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=trinidad
# City not found. Skipping...
# Processing Record 522 | Turukhansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=turukhansk
# Processing Record 523 | Anloga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=anloga
# Processing Record 524 | Bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=bubaque
# Processing Record 525 | Kattivakkam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=kattivakkam
# Processing Record 526 | Visavadar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=visavadar
# Processing Record 527 | Danjiangkou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=danjiangkou
# Processing Record 528 | Trincomalee
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=trincomalee
# Processing Record 529 | Dauphin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=dauphin
# Processing Record 530 | North Bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=north bend
# Processing Record 531 | Awbari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=awbari
# Processing Record 532 | Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=srednekolymsk
# Processing Record 533 | Pitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=pitea
# Processing Record 534 | Sikonge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=sikonge
# Processing Record 535 | San Policarpo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=san policarpo
# Processing Record 536 | Attock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=attock
# Processing Record 537 | Kaiu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=kaiu
# Processing Record 538 | Dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=dunedin
# Processing Record 539 | Perth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=perth
# Processing Record 540 | Orsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=orsk
# City not found. Skipping...
# Processing Record 541 | Dharchula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=dharchula
# Processing Record 542 | Moranbah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=moranbah
# Processing Record 543 | Fredericton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=fredericton
# City not found. Skipping...
# Processing Record 544 | Marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=marawi
# Processing Record 545 | Iskateley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=iskateley
# Processing Record 546 | Pokhara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=pokhara
# Processing Record 547 | Nuevitas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=nuevitas
# Processing Record 548 | Katobu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=katobu
# Processing Record 549 | Tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=tura
# Processing Record 550 | Moindou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=moindou
# Processing Record 551 | Poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=poum
# Processing Record 552 | Nikolayevsk-na-amure
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=nikolayevsk-na-amure
# Processing Record 553 | Oswego
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=oswego
# Processing Record 554 | Atambua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=atambua
# Processing Record 555 | Bereda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=bereda
# Processing Record 556 | Yeppoon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=yeppoon
# City not found. Skipping...
# Processing Record 557 | Horta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=horta
# City not found. Skipping...
# Processing Record 558 | Ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=ugoofaaru
# Processing Record 559 | Zaozerne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=zaozerne
# Processing Record 560 | Alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=alofi
# Processing Record 561 | Petropavlovsk-Kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=petropavlovsk-kamchatskiy
# City not found. Skipping...
# Processing Record 562 | Arcachon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=arcachon
# Processing Record 563 | Chauk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=chauk
# Processing Record 564 | Calvinia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=calvinia
# Processing Record 565 | Anito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=anito
# Processing Record 566 | Ngunguru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=ngunguru
# Processing Record 567 | Sechura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=sechura
# Processing Record 568 | Jiwani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=jiwani
# Processing Record 569 | Trapani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=trapani
# Processing Record 570 | Prince Albert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=prince albert
# Processing Record 571 | Yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=yerbogachen
# Processing Record 572 | Apatity
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=apatity
# Processing Record 573 | Tsumeb
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=tsumeb
# Processing Record 574 | Nouakchott
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=nouakchott
# Processing Record 575 | Laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=laguna
# Processing Record 576 | Great Yarmouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=great yarmouth
# City not found. Skipping...
# Processing Record 577 | Avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=avera
# Processing Record 578 | Takoradi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=takoradi
# City not found. Skipping...
# Processing Record 579 | Seydi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64c2dce9c8939e9cc8417152c799252e&q=seydi

# %%
weatherdict={"City":city_name,"Cloudiness":cloudiness,"Country":country,"Date":date,"Humidity":humidity,"Lat":lat,"Lng":lng,"Max Temp":max_temp,"Wind Speed":wind_speed}
weatherframe=pd.DataFrame(weatherdict)
weatherframe.count()
# Out:
# City          579
# Cloudiness    579
# Country       579
# Date          579
# Humidity      579
# Lat           579
# Lng           579
# Max Temp      579
# Wind Speed    579
# dtype: int64

# %%
weatherframe.to_csv('weatherframe.csv')
weatherframe.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0       Mataura          90      NZ  1562770055        92 -46.19  168.86
# 1   Khandagayty         100      MN  1562770056        98  50.73   92.07
# 2         Pevek           8      RU  1562770058        66  69.70  170.27
# 3  Boulder City           1      US  1562770059        19  35.98 -114.83
# 4     Cape Town           0      ZA  1562769969        63 -33.93   18.42
#
#    Max Temp  Wind Speed
# 0     45.95        5.75
# 1     51.53        6.85
# 2     48.29       12.06
# 3     84.00        3.36
# 4     66.99        4.70

# %%
#Latitude vs. Temperature Plot
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.scatter(lat, max_temp, marker="o", edgecolors="black")
plt.savefig("City_Lat_vs_max_temp.png")

# %%
#Latitude vs. Humidity Plot
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.scatter(lat, humidity, marker="o",edgecolors="black")
plt.savefig("city_Lat_vs_humidity.png")

# %%
#Latitude vs. Cloudiness Plot
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.scatter(lat, cloudiness, marker="o", edgecolors="black")
plt.savefig("city_Lat_vs_cloudiness.png")

# %%
#Latitude vs. Wind Speed Plot
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.scatter(lat, wind_speed, marker="o", edgecolors="black")
plt.savefig("city_Lat_vs_wind_speed.png")
